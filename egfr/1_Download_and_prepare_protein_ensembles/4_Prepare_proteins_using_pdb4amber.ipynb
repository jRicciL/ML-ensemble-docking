# %% [markdown]
# # Prepare protein conformations using `pdb4amber`
#
# - After modeling the missing regions of the PDB structures, we will use `pdb4amber` to add missing atoms.

# %%
from pathlib import Path
from glob import glob
import pdb4amber
import os

# %% [markdown]
# - List the input files.
# - Define the output directory.

# %%
OUT_MAIN   = './pdb_structures'

# Get the list of input files from modeled pdbs
INPUT_DIR = f'{OUT_MAIN}/pdb_modeled'
input_files = sorted(glob(f'{INPUT_DIR}/*pdb'))

# Define the output directory
OUTPUT_DIR = f'{OUT_MAIN}/pdb_prepared'
Path(OUTPUT_DIR).mkdir(parents = True, exist_ok = True)

# %% [markdown]
# <h3 style='color: black; background-color: #F9E5AB; padding: 5px;'>
#     Important!
# </h3>
#
# #### For EGFR only:
#
# Just for this protein we will remove the first 35 residues of all models, as this region was not present in all pdb entries and it was not correctly modeled. We will assume that removing this region will have no impact during the docking simulations.

# %% [markdown]
# #### Visualize the region to be removed

# %%
import nglview as nv
import pytraj as pyt
import numpy as np
import prody

ref_struc_id    = '7a2a'
ref_ligand_name = '7G9'
ref_prot = prody.parsePDB(ref_struc_id).select('chain A')
pocket_sel = ref_prot.select(
    f'within 7 of resname {ref_ligand_name} and protein')
start_position = 675
pocket_residues = [str(i - start_position) 
                   for i in np.unique(
                       pocket_sel.getResnums())
                  ]
pocket_residues_str = ' '.join(pocket_residues)
lig_resnum = ref_prot.select(
                       f'resname {ref_ligand_name}'
                 ).getResnums()[0]

# Load the models using pytraj
crys_ensamble = pyt.iterload(input_files, top = input_files[0])
view = nv.show_pytraj(crys_ensamble)
view.clear_representations()
view.add_cartoon(selection = '%s' % list(range(0, 275)), color = 'white')
view.add_cartoon(selection = '%s' % list(range(0, 35)), color = 'red')
view.add_licorice(
    selection = pocket_residues_str, 
    color='cyan')
view
# Out:
# NGLWidget(max_frame=174)

# %%
OUTPUT_DIR_TEMP = f'{OUT_MAIN}/pdb_prepared_temp'
Path(OUTPUT_DIR_TEMP).mkdir(parents = True, exist_ok = True)

for i, file in enumerate(input_files):
    name = file.split('/')[-1]
    pyt.write_traj(filename = f'{OUTPUT_DIR_TEMP}/{name}',
                   traj = crys_ensamble[':35-275'],
                   frame_indices = [i])

# %% [markdown]
# ### Perform the preparation

# %%
# Give the saved structures as input
input_files = sorted(glob(f'{OUTPUT_DIR_TEMP}/*pdb'))

for pdb_file in input_files:
    pdb_id = Path(pdb_file).stem.rsplit('_')[0]
    print(F"Preparing the {pdb_id} structure.")

    ensamble_file = f'{OUTPUT_DIR}/{pdb_id}_ENS.pdb'
    pdb4amber.run(arg_pdbin = pdb_file,
                  arg_add_missing_atoms = True, 
                  arg_pdbout = ensamble_file)
    # Remove the unnecessary files
    os.remove(f'{OUTPUT_DIR}/{pdb_id}_ENS_nonprot.pdb')
    os.remove(f'{OUTPUT_DIR}/{pdb_id}_ENS_sslink')
    os.remove(f'{OUTPUT_DIR}/{pdb_id}_ENS_renum.txt')
# Out:
# Preparing the 1m14 structure.
# Preparing the 1m17 structure.
# Preparing the 1xkk structure.
# Preparing the 2eb2 structure.
# Preparing the 2eb3 structure.
# Preparing the 2gs2 structure.
# Preparing the 2gs6 structure.
# Preparing the 2gs7 structure.
# Preparing the 2itn structure.
# Preparing the 2ito structure.
# Preparing the 2itp structure.
# Preparing the 2itq structure.
# Preparing the 2itt structure.
# Preparing the 2itu structure.
# Preparing the 2itv structure.
# Preparing the 2itw structure.
# Preparing the 2itx structure.
# Preparing the 2ity structure.
# Preparing the 2itz structure.
# Preparing the 2j5e structure.
# Preparing the 2j5f structure.
# Preparing the 2j6m structure.
# Preparing the 2jit structure.
# Preparing the 2jiu structure.
# Preparing the 2jiv structure.
# Preparing the 2rf9 structure.
# Preparing the 2rfd structure.
# Preparing the 2rfe structure.
# Preparing the 2rgp structure.
# Preparing the 3bel structure.
# Preparing the 3gop structure.
# Preparing the 3gt8 structure.
# Preparing the 3ika structure.
# Preparing the 3lzb structure.
# Preparing the 3poz structure.
# Preparing the 3ug1 structure.
# Preparing the 3ug2 structure.
# Preparing the 3vjn structure.
# Preparing the 3vjo structure.
# Preparing the 3w2o structure.
# Preparing the 3w2p structure.
# Preparing the 3w2q structure.
# Preparing the 3w2r structure.
# Preparing the 3w2s structure.
# Preparing the 3w32 structure.
# Preparing the 3w33 structure.
# Preparing the 4g5j structure.
# Preparing the 4g5p structure.
# Preparing the 4hjo structure.
# Preparing the 4i1z structure.
# Preparing the 4i20 structure.
# Preparing the 4i21 structure.
# Preparing the 4i22 structure.
# Preparing the 4i24 structure.
# Preparing the 4jq7 structure.
# Preparing the 4jq8 structure.
# Preparing the 4jr3 structure.
# Preparing the 4jrv structure.
# Preparing the 4ll0 structure.
# Preparing the 4lqm structure.
# Preparing the 4r3p structure.
# Preparing the 4r3r structure.
# Preparing the 4r5s structure.
# Preparing the 4riw structure.
# Preparing the 4rix structure.
# Preparing the 4riy structure.
# Preparing the 4rj4 structure.
# Preparing the 4rj5 structure.
# Preparing the 4rj6 structure.
# Preparing the 4rj7 structure.
# Preparing the 4rj8 structure.
# Preparing the 4tks structure.
# Preparing the 4zau structure.
# Preparing the 4zjv structure.
# Preparing the 4zse structure.
# Preparing the 5c8k structure.
# Preparing the 5c8m structure.
# Preparing the 5c8n structure.
# Preparing the 5cal structure.
# Preparing the 5can structure.
# Preparing the 5cao structure.
# Preparing the 5cap structure.
# Preparing the 5caq structure.
# Preparing the 5cas structure.
# Preparing the 5cau structure.
# Preparing the 5cav structure.
# Preparing the 5cnn structure.
# Preparing the 5cno structure.
# Preparing the 5czh structure.
# Preparing the 5czi structure.
# Preparing the 5d41 structure.
# Preparing the 5edp structure.
# Preparing the 5edq structure.
# Preparing the 5edr structure.
# Preparing the 5em5 structure.
# Preparing the 5em6 structure.
# Preparing the 5em7 structure.
# Preparing the 5em8 structure.
# Preparing the 5fed structure.
# Preparing the 5fee structure.
# Preparing the 5feq structure.
# Preparing the 5gmp structure.
# Preparing the 5gnk structure.
# Preparing the 5gty structure.
# Preparing the 5gtz structure.
# Preparing the 5hcx structure.
# Preparing the 5hcy structure.
# Preparing the 5hcz structure.
# Preparing the 5hg5 structure.
# Preparing the 5hg7 structure.
# Preparing the 5hg8 structure.
# Preparing the 5hg9 structure.
# Preparing the 5hib structure.
# Preparing the 5hic structure.
# Preparing the 5j9y structure.
# Preparing the 5j9z structure.
# Preparing the 5jeb structure.
# Preparing the 5u8l structure.
# Preparing the 5ug8 structure.
# Preparing the 5ug9 structure.
# Preparing the 5uga structure.
# Preparing the 5ugc structure.
# Preparing the 5uwd structure.
# Preparing the 5x26 structure.
# Preparing the 5x27 structure.
# Preparing the 5x28 structure.
# Preparing the 5x2a structure.
# Preparing the 5x2c structure.
# Preparing the 5x2f structure.
# Preparing the 5x2k structure.
# Preparing the 5xdk structure.
# Preparing the 5xdl structure.
# Preparing the 5xgm structure.
# Preparing the 5xgn structure.
# Preparing the 5y25 structure.
# Preparing the 5y9t structure.
# Preparing the 5yu9 structure.
# Preparing the 5zto structure.
# Preparing the 5zwj structure.
# Preparing the 6d8e structure.
# Preparing the 6duk structure.
# Preparing the 6jrj structure.
# Preparing the 6jrk structure.
# Preparing the 6jrx structure.
# Preparing the 6jwl structure.
# Preparing the 6jx0 structure.
# Preparing the 6jx4 structure.
# Preparing the 6jxt structure.
# Preparing the 6jz0 structure.
# Preparing the 6p1d structure.
# Preparing the 6p1l structure.
# Preparing the 6p8q structure.
# Preparing the 6s89 structure.
# Preparing the 6s8a structure.
# Preparing the 6s9b structure.
# Preparing the 6s9c structure.
# Preparing the 6s9d structure.
# Preparing the 6tfu structure.
# Preparing the 6tfv structure.
# Preparing the 6tfw structure.
# Preparing the 6tfy structure.
# Preparing the 6tfz structure.
# Preparing the 6tg0 structure.
# Preparing the 6tg1 structure.
# Preparing the 6v5n structure.
# Preparing the 6v5p structure.
# Preparing the 6v66 structure.
# Preparing the 6v6k structure.
# Preparing the 6v6o structure.
# Preparing the 6vh4 structure.
# Preparing the 6vhn structure.
# Preparing the 6vhp structure.
# Preparing the 6z4b structure.
# Preparing the 6z4d structure.
# Preparing the 7a2a structure.
