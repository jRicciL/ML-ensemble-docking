# %% [markdown]
# # Get Molecular Libraries
#
# - `obabel` is assumed to be installed: https://anaconda.org/openbabel/openbabel
# - Molecules will be exported into `sdf` and `mol2` formats for loading with `rdkit` and docking with [SMINA](https://sourceforge.net/projects/smina/), respectively.

# %%
import wget
import gzip
import shutil
import tarfile
import pandas as pd
from glob import glob
import subprocess as sp
from pathlib import Path

# %%
LIB_DIR = './datasets/'

# %% [markdown]
# <h4 style='color: black; background-color: #F9E5AB; padding: 5px;'>
#     Important!
# </h4>
#
# - The `prot_name` is used to download the specific protein target's dataset.
# - To proceed with a new protein different to CDK2, FXa, EGFR, and HSP90, please double check the name of the protein as it appears in the respective dataset.

# %%
prot_name = 'egfr'

# %% [markdown]
# ## DEKOIS 2.0
#
# Downloaded from: http://www.pharmchem.uni-tuebingen.de/dekois/

# %%
# Datasets url
DEKOIS_URL = 'http://www.pharmchem.uni-tuebingen.de/dekois/data/'
dekois_actives_url = f'{DEKOIS_URL}/DEKOIS2_actives/{prot_name.upper()}.sdf.gz'
dekois_decoys_url  = f'{DEKOIS_URL}/DEKOIS2_decoys/{prot_name.upper()}_Celling-v1.12_decoyset.sdf.gz'

# Output directory
DEKOIS_DIR = f'{LIB_DIR}/DEKOIS2/'
Path(DEKOIS_DIR).mkdir(exist_ok = True, parents = True)

# Download and extract each file
for lib_set in [dekois_actives_url, dekois_decoys_url]:
    # Download it
    set_path = Path(DEKOIS_DIR, lib_set.split('/')[-1])
    if not set_path.exists():
        wget.download(lib_set, out = DEKOIS_DIR)

    # Extract the files
    with gzip.open(str(set_path)) as f_in, \
          open(str(set_path).split('.gz')[0], 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)
        
# Create the output directories
Path(f'{DEKOIS_DIR}/mol2').mkdir(exist_ok = True)
Path(f'{DEKOIS_DIR}/sdf').mkdir(exist_ok = True)

# %%
# %%bash -s $DEKOIS_DIR $PROT
# # Split the molecules into individual files
#
# # MOL2 Files
# # Actives
# obabel $1/${2}.sdf -O $1/mol2/ligand_.mol2 -m
# # Decoys
# obabel $1/${2}_Celling-v1.12_decoyset.sdf -O $1/mol2/decoy_.mol2 -m
#
# # SDF Files
# # Actives
# obabel $1/${2}.sdf -O $1/sdf/ligand_.sdf -m
# # Decoys
# obabel $1/${2}_Celling-v1.12_decoyset.sdf -O $1/sdf/decoy_.sdf -m
# Out:
# 40 molecules converted
# 40 files output. The first is ./datasets//DEKOIS2//mol2/ligand_1.mol2
# 1200 molecules converted
# 1200 files output. The first is ./datasets//DEKOIS2//mol2/decoy_1.mol2
# 40 molecules converted
# 40 files output. The first is ./datasets//DEKOIS2//sdf/ligand_1.sdf
# ==============================
# *** Open Babel Error  in TetStereoToWedgeHash
#   Failed to set stereochemistry as unable to find an available bond
# 1200 molecules converted
# 1200 files output. The first is ./datasets//DEKOIS2//sdf/decoy_1.sdf

# %% [markdown]
# ## DUD-2006
#
# Downloaded from: http://www.pharmchem.uni-tuebingen.de/dekois/

# %%
# Datasets url
DUD_URL = 'http://dud.docking.org/inhibox/allDUDfiles_Gasteiger.tar.gz'

# Output directory
DUD_DIR = f'{LIB_DIR}/DUD/'
Path(DUD_DIR).mkdir(exist_ok = True)

# Download the file
set_path = Path(DUD_DIR, DUD_URL.split('/')[-1])
if not set_path.exists():
    wget.download(DUD_URL, out = DUD_DIR)

# Extract the molecules file
with tarfile.open(str(set_path)) as t:
    # ligands
    ligands_file = f'{prot_name}_ligands_Gasteiger.mol2'

#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00550208)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00553561)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00555838)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00558869)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00563120)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00563123)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00563603)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00564739)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00574045)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00574163)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00577520)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00577578)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00577579)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00583117)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00590373)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00591295)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00608525)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00608526)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00611805)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00613399)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00615151)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00617681)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00619762)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00624999)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00629281)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00629535)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00644440)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00644441)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00653432)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00656829)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00659370)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00693677)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00709345)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00714089)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00753722)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00794862)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00794865)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00794866)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00796280)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00798415)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00803263)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00811122)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00811262)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00811267)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00814334)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00819085)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00819107)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00819141)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00819539)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00840297)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00844736)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00854888)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00854889)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00881693)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00885053)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00888818)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00888821)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC00904222)
#
# ==============================
# ...
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03867941)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03867946)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03867962)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03867964)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03867965)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03867966)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03867967)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03867971)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03867973)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03867974)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03868041)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03868052)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03868089)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03868257)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03868260)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03868264)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03868267)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03868442)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03868583)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03868643)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03869095)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03869097)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03869098)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03869104)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03876241)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03876632)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03878106)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03878198)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03896479)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03896502)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03899381)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03899866)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03902085)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03902579)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03902933)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03902937)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03906271)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03906274)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03907619)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03907665)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03908242)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03909978)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03909982)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03927149)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03936860)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03945095)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03967871)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03969087)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03969088)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03969412)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03969906)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03970014)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03971032)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03971032)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03971333)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03976503)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03977379)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03979973)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03984657)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03984848)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03987829)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03987880)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03992764)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03997173)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03997183)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03997184)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC03997185)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04002627)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04003159)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04004958)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04005380)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04007953)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04013830)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04023832)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04032221)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04032980)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04033166)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04082855)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04102756)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04108686)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04113172)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04115433)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04116100)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04126188)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04129144)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04131692)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04136719)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04156136)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04156591)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04160157)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04170917)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04274709)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04274709)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04299487)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04403810)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04406373)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04406373)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04406453)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04406453)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04413568)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04427553)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04475637)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04478193)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04481372)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04484723)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04484723)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04492542)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04492542)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04492815)
#
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Failed to kekulize aromatic bonds in MOL2 file (title is ZINC04492815)
#
# 15996 molecules converted
# 15996 files output. The first is ./datasets//DUD//allDUDfiles_Gasteiger/../sdf/decoy_1.sdf

# %% [markdown]
# ## Cocrystalized molecules
# Molecules obtained with the notebook `../1_Download_and_prepare_protein_ensembles/5_Get_cocrystalized_molecules_from_PDB`.

# %%
# Cocrystalized ligands directory
DIR_MAIN      = '../1_Download_and_prepare_protein_ensembles/pdb_structures'
DIR_PREP_LIGS = f'{DIR_MAIN}/pocket_ligands'


# Output directory
COCRYS_DIR = f'{LIB_DIR}/COCRYS/'
Path(COCRYS_DIR).mkdir(exist_ok = True)

# List all available files and create a 
# dictionary with the molecule name as key
# Duplicates will be removed in futher notebooks
list_of_files = sorted(glob(f'{DIR_PREP_LIGS}/*pdb'))
cocrys_mols = {file.split('/')[-1].split('.pdb')[0]: file 
                 for file in list_of_files
              }
print(f'{len(cocrys_mols)} unique compounds of ' +\
      f'{len(list_of_files)} cocrystalized molecules')

# MOL2 Files
Path(f'{COCRYS_DIR}/mol2').mkdir(exist_ok = True)
# Convert the molecules to mol2 using obabel
for name, file in cocrys_mols.items():
    sp.run(
        f'''
        obabel -ipdb {file} \
            -omol2 -O {COCRYS_DIR}/mol2/{name}.mol2 \
            -p 7.0 --gen3d --partialcharge gasteiger
        ''',
        shell = True
    )

# SDF Files
Path(f'{COCRYS_DIR}/sdf').mkdir(exist_ok = True)
# Convert the molecules to sdf using obabel
for name, file in cocrys_mols.items():
    sp.run(
        f'''
        obabel -ipdb {file} \
            -osdf -O {COCRYS_DIR}/sdf/{name}.sdf \
            -p 7.0 --gen3d --partialcharge gasteiger
        ''',
        shell = True
    )
# Out:
# 159 unique compounds of 159 cocrystalized molecules

# %% [markdown]
# Finished!
